# %% [markdown]
# #Q1) Prediction of fraudulent transactions

# %% [markdown]
# A bank monitors credit-card transactions for possible fraud.
#
# For each transaction, let the sample space be
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# where:
#
# * $\omega_1$: low-risk customer, legitimate transaction,
# * $\omega_2$: low-risk customer, fraudulent transaction,
# * $\omega_3$: high-risk customer, legitimate transaction,
# * $\omega_4$: high-risk customer, fraudulent transaction.
#
# Assume the probabilities are
#
# $$
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $$
#
# Let $X:\Omega\to\mathbb R$ denote the fraud indicator:
#
# $$
# X(\omega_1)=0,\qquad
# X(\omega_2)=1,\qquad
# X(\omega_3)=0,\qquad
# X(\omega_4)=1.
# $$
#
# Thus $X=1$ means the transaction is fraudulent, and $X=0$ means it is legitimate.
#
# Now suppose the bank does not observe the full outcome $\omega$, but only the customer's risk class. Define $Y:\Omega\to\mathbb R$ by
#
# $$
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $$
#
# Thus:
#
# * $Y=0$ means “low-risk customer,”
# * $Y=1$ means “high-risk customer.”
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# 2. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 3. Explain why $E[X\mid Y]$ must be $\sigma(Y)$-measurable, and therefore must be constant on the sets $\{ \omega_1,\omega_2\}$ and $\{\omega_3,\omega_4\}$.
#
# 4. Compute $E[X\mid Y]$ explicitly and show that
#
# $$
# E[X\mid Y]= \frac{1}{6} \mathbb{1}_{\{Y=0\}} + \frac{1}{2} \mathbb{1}_{\{Y=1\}}
# $$
#
# 5. Verify the defining property of conditional expectation by checking that for every set $A\in\sigma(Y)$,
#
# $$
# \int_A E[X\mid Y]\,dP=\int_A X\,dP.
# $$
#
# 6. Find the Conditional PMF $p_{X|Y}(x \mid y)$.
#
# 7. Verify the identity:
# $$\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)$$.
#
# 8. Calculate the **Mean Square Error (MSE)**
#
# 9. How would the **Mean Square Error (MSE)** change if the bank decided to ignore the customer risk class $Y$ and instead used the global average fraud rate ($E[X] = 0.30$) as a constant estimate for every transaction? Calculate this error and explain its relationship to the **Law of Total Variance**.
#
# 10. Using the joint distribution of $(X, Y)$ derived from the sample space:
#
#     a) Compute the entropy $H(X)$, representing the bank's initial uncertainty regarding fraud.
#
#     b) Compute the conditional entropy $H(X \mid Y)$, representing the uncertainty remaining after the customer's risk class is revealed.
#
#     c) Calculate the Mutual Information $I(X; Y)$.
#
#     d) Based on these values, what percentage of the total uncertainty about fraud is removed by knowing the customer's risk class?

# %% [markdown]
# ## Sample Answer

# %% [markdown]
# ### Q1.1

# %% [markdown]
# The probability space is
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# $$
# \mathfrak F=\mathfrak P(\Omega),
# $$
#
# and the probability measure $P$ is defined by
#
# $$
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $$
#
# Since
#
# $$
# 0.50+0.10+0.20+0.20=1,
# $$
#
# this is a valid probability measure.

# %% [markdown]
# ###Q1.2

# %% [markdown]
# The random variable $Y$ is defined by
#
# $$
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $$
#
# Thus the inverse images of the values of $Y$ are
#
# $$
# Y^{-1}({0})=\{\omega_1,\omega_2\},
# $$
#
# and
#
# $$
# Y^{-1}({1})=\{\omega_3,\omega_4\}.
# $$
#
# Therefore the $\sigma$-algebra generated by $Y$ is
#
# $$
# \sigma(Y)=\left\{\varnothing,\Omega,\{\omega_1,\omega_2\},\{\omega_3,\omega_4\}\right\}.
# $$

# %% [markdown]
# ### Q1.3

# %% [markdown]
# By definition, $E[X\mid Y]$ must be $\sigma(Y)$-measurable. This means it can depend only on the value of $Y$, not on the full outcome $\omega$. That is $E[X\mid Y]=g(Y)$ for some measurable map $g$.
#
# Since $\sigma(Y)$ can distinguish only the two sets
#
# $$
# \{\omega_1,\omega_2\}
# \quad \text{and} \quad
# \{\omega_3,\omega_4\},
# $$
#
# the random variable $E[X\mid Y]$ must be constant on each of these sets.
#
# So we write
#
# $$
# E[X\mid Y](\omega)=
# \begin{cases}
# a, & \omega\in\{\omega_1,\omega_2\},\\
# b, & \omega\in\{\omega_3,\omega_4\},
# \end{cases}
# $$
#
# for some constants $a$ and $b$ to be determined.

# %% [markdown]
# ###Q1.4

# %% [markdown]
# To find $a$ and $b$, we use the defining property of conditional expectation.
#
# On the set $\{\omega_1,\omega_2\}$,
#
# $$
# \int_{\{\omega_1,\omega_2\}} E[X\mid Y]\,dP=\int_{\{\omega_1,\omega_2\}} X\,dP.
# $$
#
# The left-hand side is
#
# $$
# a\cdot P(\{\omega_1,\omega_2\})=a(0.50+0.10)=0.60a.
# $$
#
# The right-hand side is
#
# $$
# 0\cdot 0.50 + 1\cdot 0.10 = 0.10.
# $$
#
# So
#
# $$
# 0.60a=0.10,
# $$
#
# hence
#
# $$
# a=\frac{0.10}{0.60}=\frac{1}{6}.
# $$
#
# On the set $\{\omega_3,\omega_4\}$,
#
# $$
# \int_{\{\omega_3,\omega_4\}} E[X\mid Y]\,dP=\int_{\{\omega_3,\omega_4\}} X\,dP.
# $$
#
# The left-hand side is
#
# $$
# b\cdot P(\{\omega_3,\omega_4\})=b(0.20+0.20)=0.40b.
# $$
#
# The right-hand side is
#
# $$
# 0\cdot 0.20 + 1\cdot 0.20 = 0.20.
# $$
#
# So
#
# $$
# 0.40b=0.20,
# $$
#
# hence
#
# $$
# b=\frac{0.20}{0.40}=\frac{1}{2}.
# $$
#
# Therefore
#
# $$
# E[X\mid Y](\omega)=
# \begin{cases}
# \dfrac{1}{6}, & \omega\in\{\omega_1,\omega_2\},\\
# \dfrac{1}{2}, & \omega\in\{\omega_3,\omega_4\}.
# \end{cases}
# $$
#
# Equivalently, as a function of $Y$,
#
# $$
# E[X\mid Y]=
# \frac{1}{6} \mathbb{1}_{\{Y=0\}} + \frac{1}{2} \mathbb{1}_{\{Y=1\}}=
# \begin{cases}
# \dfrac{1}{6}, & Y=0,\\
# \dfrac{1}{2}, & Y=1.
# \end{cases}
# $$

# %% [markdown]
# ###Q1.5

# %% [markdown]
# We now verify the defining property
#
# $$
# \int_A E[X\mid Y]\,dP=\int_A X\,dP
# \qquad \forall A\in\sigma(Y).
# $$
#
# The sets in $\sigma(Y)$ are
#
# $$
# \varnothing,\qquad \Omega,\qquad \{\omega_1,\omega_2\},\qquad \{\omega_3,\omega_4\}.
# $$
#
# For $A=\varnothing$, both integrals are clearly $0$.
#
# For
#
# $$
# A=\{\omega_1,\omega_2\},
# $$
#
# we already computed
#
# $$
# \int_A E[X\mid Y]\,dP = \frac{1}{6}\cdot 0.60 = 0.10,
# $$
#
# and
#
# $$
# \int_A X\,dP = 0\cdot 0.50 + 1\cdot 0.10 = 0.10.
# $$
#
# For
#
# $$
# A=\{\omega_3,\omega_4\},
# $$
#
# we already computed
#
# $$
# \int_A E[X\mid Y]\,dP = \frac{1}{2}\cdot 0.40 = 0.20,
# $$
#
# and
#
# $$
# \int_A X\,dP = 0\cdot 0.20 + 1\cdot 0.20 = 0.20.
# $$
#
# For
#
# $$
# A=\Omega,
# $$
#
# we have
#
# $$
# \int_\Omega E[X\mid Y]\,dP=\frac{1}{6}\cdot 0.60 + \frac{1}{2}\cdot 0.40=0.3.
# $$
#
# Also,
#
# $$
# \int_\Omega X\,dP=0\cdot 0.50 + 1\cdot 0.10 + 0\cdot 0.20 + 1\cdot 0.20=0.30.
# $$
#
# So the defining property holds for every $A\in\sigma(Y)$.
#
# The last verification also demonstrates the Law of Total Expectation:
# $$E[E[X|Y]] = E[X]$$

# %% [markdown]
# ###Q1.6

# %% [markdown]
# Using the product rule $p_{X|Y}(x \mid y) = \frac{P(X=x, Y=y)}{P(Y=y)}$, we calculate the conditional probability of fraud ($X=1$) for each risk class:
#
# * **For $Y=0$:**
#   $$p_{X|Y}(1 \mid 0) = \frac{P(X=1, Y=0)}{P(Y=0)} = \frac{P(\{\omega_2\})}{0.60} = \frac{0.10}{0.60} = \mathbf{1/6}$$
# * **For $Y=1$:**
#   $$p_{X|Y}(1 \mid 1) = \frac{P(X=1, Y=1)}{P(Y=1)} = \frac{P(\{\omega_4\})}{0.40} = \frac{0.20}{0.40} = \mathbf{1/2}$$
#
# *(Note: The probabilities for $X=0$ are simply the complements: $5/6$ and $1/2$ respectively.)*
#
# So once the bank knows the risk class, the fraud probability changes:
#
# * for low-risk customers,
#   $$
#   P(\text{fraud}\mid Y=0)=\frac{1}{6}\approx 0.167,
#   $$
#
# * for high-risk customers,
#   $$
#   P(\text{fraud}\mid Y=1)=\frac{1}{2}=0.50.
#   $$
#
#
# This is exactly the kind of quantity a fraud detection system would use for risk scoring.

# %% [markdown]
# ###Q1.7

# %% [markdown]
# Now apply your discrete summary formula:
# $$\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)$$.
#
# * **Evaluation at $y=0$:**
#   $$\mathbb{E}[X\mid Y=0] = (0 \cdot p_{X|Y}(0 \mid 0)) + (1 \cdot p_{X|Y}(1 \mid 0)) = 0 + (1 \cdot 1/6) = \mathbf{1/6}$$
# * **Evaluation at $y=1$:**
#   $$\mathbb{E}[X\mid Y=1] = (0 \cdot p_{X|Y}(0 \mid 1)) + (1 \cdot p_{X|Y}(1 \mid 1)) = 0 + (1 \cdot 1/2) = \mathbf{1/2}$$

# %% [markdown]
# ###Q1.8

# %% [markdown]
# We compute the Minimum Mean Square Error (MMSE), which represents the optimal error (irreducible uncertainty) when using the estimate $\mathbb{E}[X|Y]$. As derived previously, this is given by the expected conditional variance:
# $$\text{MSE}_{\text{min}} = \mathbb{E}[(X - \mathbb{E}[X \mid Y])^2] = \mathbb{E}[\mathrm{Var}(X \mid Y)].$$
#
# First, we find the conditional variance for each risk class $y \in \{0, 1\}$. Since $X$ is a Bernoulli indicator variable given $Y=y$, the variance is $p(1-p)$:
#
# For $Y=0$: $\mathrm{Var}(X \mid Y=0) = \frac{1}{6} \left(1 - \frac{1}{6}\right) = \frac{1}{6} \cdot \frac{5}{6} = \frac{5}{36}$.
#
# For $Y=1$: $\mathrm{Var}(X \mid Y=1) = \frac{1}{2} \left(1 - \frac{1}{2}\right) = \frac{1}{2} \cdot \frac{1}{2} = \frac{1}{4}.$
#
# Now, we take the expectation over the distribution of $Y$:
#
# \begin{align*}\mathbb{E}[\mathrm{Var}(X \mid Y)] &= \mathrm{Var}(X \mid Y=0)P(Y=0) + \mathrm{Var}(X \mid Y=1)P(Y=1) \\
# &= \left(\frac{5}{36} \cdot 0.60\right) + \left(\frac{1}{4} \cdot 0.40\right) \\
# &= \left(\frac{5}{36} \cdot \frac{3}{5}\right) + \left(\frac{1}{4} \cdot \frac{2}{5}\right) \\
# &= \frac{1}{12} + \frac{1}{10} = \frac{5+6}{60} = \mathbf{\frac{11}{60} \approx 0.1833}.
# \end{align*}
# This value, $0.1833$, is the lowest possible average squared error the bank can achieve. Any other estimate based on risk class would result in an error strictly greater than this.

# %% [markdown]
# ###Q1.9

# %% [markdown]
# %%latex
# \section*{Verification of the Law of Total Variance}
#
# \subsection*{1. Total Variance of $X$}
# Given the probability $p = 0.30$, $X$ is a Bernoulli random variable. Its total variance is calculated as:
# $$ \text{Var}(X) = p(1-p) $$
# $$ \text{Var}(X) = 0.30 \times (1 - 0.30) = 0.30 \times 0.70 = 0.21 $$
#
# \pagebreak
#
# \subsection*{2. Optimal Error (Conditional Variance)}
# The minimum Mean Squared Error ($\text{MSE}_{\min}$), which represents the expected conditional variance $E[\text{Var}(X|Y)]$, is given as:
# $$ \text{MSE}_{\min} = E[\text{Var}(X|Y)] = \frac{11}{60} \approx 0.18333 $$
#
# ---
#
# \subsection*{3. Explained Variance (Variance of the Conditional Expectation)}
# To find $\text{Var}(E[X|Y])$, we use the formula:
# $$ \text{Var}(E[X|Y]) = E[(E[X|Y])^2] - (E[X])^2 $$
#
# First, we calculate the components for $E[(E[X|Y])^2]$:
# \begin{align*}
# \text{Term 1} &= \frac{1}{36} \times 0.6 = 0.01667 \\
# \text{Term 2} &= \frac{1}{4} \times 0.4 = 0.10000
# \end{align*}
#
# Summing these terms gives the second moment of the conditional expectation:
# $$ E[(E[X|Y])^2] = 0.01667 + 0.10000 = 0.11667 $$
#
# Next, we subtract the square of the expectation $(E[X])^2$:
# $$ (E[X])^2 = (0.30)^2 = 0.09 $$
#
# Thus, the explained variance is:
# $$ \text{Var}(E[X|Y]) = 0.11667 - 0.09 = 0.02667 \quad \left(\text{or } \frac{4}{150}\right) $$
#
# ---
#
# \subsection*{4. Verification via the Law of Total Variance}
# The Law of Total Variance states that:
# $$ \text{Var}(X) = E[\text{Var}(X|Y)] + \text{Var}(E[X|Y]) $$
#
# Substituting our calculated values:
# $$ 0.21 = \frac{11}{60} + 0.02667 $$
# $$ 0.21 = 0.18333 + 0.02667 $$
# $$ 0.21 = 0.21 \quad \checkmark $$
#
# The identity holds perfectly.

# %% [markdown]
# ### Q1.10 Quantifying Information Gain

# %% [markdown]
# ## **Information Theory Calculations**
#
# ### **1. Probability Distribution**
#
# Given the joint probabilities $P(X, Y)$, we first compute the marginal probabilities:
#
# $$\begin{array}{cc|cc|c}
# & & \multicolumn{2}{c|}{X} & \\
# & & 0 & 1 & P(Y) \\
# \hline
# \multirow{2}{*}{Y} & 0 & 0.50 & 0.10 & 0.60 \\
# & 1 & 0.20 & 0.20 & 0.40 \\
# \hline
# & P(X) & 0.70 & 0.30 & 1.00
# \end{array}$$
#
# *   **Marginal Probabilities of $Y$:**
#     *   $P(Y=0) = 0.50 + 0.10 = 0.60$
#     *   $P(Y=1) = 0.20 + 0.20 = 0.40$
#
# *   **Marginal Probabilities of $X$:**
#     *   $P(X=0) = 0.50 + 0.20 = 0.70$
#     *   $P(X=1) = 0.10 + 0.20 = 0.30$
#
# ---
#
# ### **2. Conditional Probabilities**
#
# Using the formula $P(X|Y) = \frac{P(X, Y)}{P(Y)}$:
#
# *   **Given $Y=0$:**
#     *   $P(X=1|Y=0) = \frac{0.10}{0.60} \approx 0.1667$
#     *   $P(X=0|Y=0) = \frac{0.50}{0.60} \approx 0.8333$
#
# *   **Given $Y=1$:**
#     *   $P(X=1|Y=1) = \frac{0.20}{0.40} = 0.50$
#     *   $P(X=0|Y=1) = \frac{0.20}{0.40} = 0.50$
#
# ---
#
# ### **3. Conditional Entropies**
#
# The Shannon entropy for a distribution is defined as $H(V) = -\sum p_i \log_2 p_i$.
#
# *   **Specific Conditional Entropies:**
#     $$H(X|Y=0) = -\left( \frac{1}{6}\log_2\frac{1}{6} + \frac{5}{6}\log_2\frac{5}{6} \right) \approx 0.6500 \text{ bits}$$
#     $$H(X|Y=1) = -\left( 0.5\log_2 0.5 + 0.5\log_2 0.5 \right) = 1.0000 \text{ bit}$$
#
# *   **Total Conditional Entropy $H(X|Y)$:**
#     $$H(X|Y) = P(Y=0)H(X|Y=0) + P(Y=1)H(X|Y=1)$$
#     $$H(X|Y) = (0.60 \times 0.6500) + (0.40 \times 1.0000)$$
#     $$H(X|Y) \approx 0.7900 \text{ bits}$$
#
# ---
#
# ### **4. Entropy of $X$ and Mutual Information**
#
# *   **Entropy $H(X)$:**
#     $$H(X) = -(0.70\log_2 0.70 + 0.30\log_2 0.30) \approx 0.8813 \text{ bits}$$
#
# *   **Mutual Information $I(X; Y)$:**
#     $$I(X; Y) = H(X) - H(X|Y)$$
#     $$I(X; Y) = 0.8813 - 0.7900$$
#     $$I(X; Y) \approx 0.0913 \text{ bits}$$

# %% [markdown]
# # Q2) Conditional Density of the Multivariate Gaussian

# %% [markdown]
# Let $\mathbf{Z}$ be the concatenated random matrix
# $\mathbf{Z} = \begin{bmatrix} \mathbf{X} \\ \mathbf{Y} \end{bmatrix} \in \mathbb{R}^{n+m}$.
#
#
# The random variable $\mathbf{Z}$ is said to have a **joint multivariate normal distribution** if every linear combination of its components follows a univariate normal distribution.
#
# For $\mathbf{Z}$ to possess a **joint density function** (meaning its distribution is absolutely continuous with respect to the Lebesgue measure on $\mathbb{R}^{n+m}$), its covariance matrix must be non-singular (positive definite).
#
#
# The joint density function $f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z})$ for $\mathbf{z} \in \mathbb{R}^{n+m}$ is given by:
#
# $$f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) = \frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}} \exp\left( -\frac{1}{2} (\mathbf{z} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{z} - \boldsymbol{\mu}) \right).$$
#
# Here:
#
# * **Mean ($\boldsymbol{\mu}$):** $\boldsymbol{\mu} = E[\mathbf{Z}] = \begin{bmatrix} \boldsymbol{\mu}_X \\ \boldsymbol{\mu}_Y \end{bmatrix} \in \mathbb{R}^{n+m}$, where $\boldsymbol{\mu}_X \in \mathbb{R}^n$ and $\boldsymbol{\mu}_Y \in \mathbb{R}^m$.
# * **Covariance Matrix ($\boldsymbol{\Sigma}$):** A symmetric, positive definite matrix $\boldsymbol{\Sigma} \in \mathbb{R}^{(n+m) \times (n+m)}$ partitioned as:
# $$\boldsymbol{\Sigma} = \begin{bmatrix} \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\ \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY} \end{bmatrix}$$
#     * $\boldsymbol{\Sigma}_{XX} = \text{Var}(\mathbf{X})$ (size $n \times n$)
#     * $\boldsymbol{\Sigma}_{YY} = \text{Var}(\mathbf{Y})$ (size $m \times m$)
#     * $\boldsymbol{\Sigma}_{XY} = \text{Cov}(\mathbf{X}, \mathbf{Y}) = \boldsymbol{\Sigma}_{YX}^T$ (size $n \times m$)
# * **Determinant ($|\boldsymbol{\Sigma}|$):** The normalization factor ensuring the total integral is 1.
#
# Show that the conditional distribution is given by $f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y})$
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\mathbf{S}_{XX}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X\mid Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right),$$
# where
# * $\boldsymbol{\Sigma}_{X\mid Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$
# * $\boldsymbol{\mu}^* = \boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_y)$

# %% [markdown]
# ## Sample Answer

# %% [markdown]
# ## Derivation of the Conditional Multivariate Normal Distribution
#
# To find the conditional density $f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y})$, we use the definition of conditional probability:
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{f_{\mathbf{X}, \mathbf{Y}}(\mathbf{x}, \mathbf{y})}{f_{\mathbf{Y}}(\mathbf{y})}$$
#
# where $f_{\mathbf{X}, \mathbf{Y}}(\mathbf{x}, \mathbf{y})$ is the joint density and $f_{\mathbf{Y}}(\mathbf{y})$ is the marginal density of $\mathbf{Y}$, given by:
#
# $$f_{\mathbf{Y}}(\mathbf{y}) = \frac{1}{\sqrt{(2\pi)^m |\boldsymbol{\Sigma}_{YY}|}} \exp\left( -\frac{1}{2} (\mathbf{y} - \boldsymbol{\mu}_Y)^T \boldsymbol{\Sigma}_{YY}^{-1} (\mathbf{y} - \boldsymbol{\mu}_Y) \right)$$
#
# ---
#
# ### 1. Matrix Inversion via Block Matrices
# To evaluate the exponent of the joint density, we need the inverse of the partitioned covariance matrix $\boldsymbol{\Sigma}$. Using the **Schur complement** of $\boldsymbol{\Sigma}_{YY}$, which we define as $\boldsymbol{\Sigma}_{X|Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$, the block inverse is given by:
#
# $$\boldsymbol{\Sigma}^{-1} = \begin{bmatrix} \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\ \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY} \end{bmatrix}^{-1} = \begin{bmatrix} \boldsymbol{\Sigma}_{X|Y}^{-1} & -\boldsymbol{\Sigma}_{X|Y}^{-1}\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1} \\ -\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{X|Y}^{-1} & \boldsymbol{\Sigma}_{YY}^{-1} + \boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{X|Y}^{-1}\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1} \end{bmatrix}$$
#
# We can factorize this inverse matrix as:
#
# $$\boldsymbol{\Sigma}^{-1} = \begin{bmatrix} \mathbf{I}_n & \mathbf{0} \\ -\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX} & \mathbf{I}_m \end{bmatrix}^T \begin{bmatrix} \boldsymbol{\Sigma}_{X|Y}^{-1} & \mathbf{0} \\ \mathbf{0} & \boldsymbol{\Sigma}_{YY}^{-1} \end{bmatrix} \begin{bmatrix} \mathbf{I}_n & \mathbf{0} \\ -\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX} & \mathbf{I}_m \end{bmatrix}$$
#
# ---
#
# ### 2. Simplifying the Quadratic Form
# Let $\tilde{\mathbf{x}} = \mathbf{x} - \boldsymbol{\mu}_X$ and $\tilde{\mathbf{y}} = \mathbf{y} - \boldsymbol{\mu}_Y$. The quadratic form in the joint density's exponent is:
#
# $$Q = (\mathbf{z} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{z} - \boldsymbol{\mu}) = \begin{bmatrix} \tilde{\mathbf{x}} \\ \tilde{\mathbf{y}} \end{bmatrix}^T \boldsymbol{\Sigma}^{-1} \begin{bmatrix} \tilde{\mathbf{x}} \\ \tilde{\mathbf{y}} \end{bmatrix}$$
#
# Applying the factorization of $\boldsymbol{\Sigma}^{-1}$:
#
# $$\begin{bmatrix} \mathbf{I}_n & \mathbf{0} \\ -\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX} & \mathbf{I}_m \end{bmatrix} \begin{bmatrix} \tilde{\mathbf{x}} \\ \tilde{\mathbf{y}} \end{bmatrix} = \begin{bmatrix} \tilde{\mathbf{x}} \\ \tilde{\mathbf{y}} - \boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}\tilde{\mathbf{x}} \end{bmatrix} \text{ (not optimal, let's use the alternative row operations form)}$$
#
# Alternatively, expanding $Q$ using the block inverse components yields:
#
# $$Q = \tilde{\mathbf{x}}^T \boldsymbol{\Sigma}_{X|Y}^{-1} \tilde{\mathbf{x}} - 2\tilde{\mathbf{x}}^T \boldsymbol{\Sigma}_{X|Y}^{-1}\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\tilde{\mathbf{y}} + \tilde{\mathbf{y}}^T \left( \boldsymbol{\Sigma}_{YY}^{-1} + \boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}\boldsymbol{\Sigma}_{X|Y}^{-1}\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1} \right) \tilde{\mathbf{y}}$$
#
# Grouping the terms containing $\boldsymbol{\Sigma}_{X|Y}^{-1}$:
#
# $$Q = \left( \tilde{\mathbf{x}} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\tilde{\mathbf{y}} \right)^T \boldsymbol{\Sigma}_{X|Y}^{-1} \left( \tilde{\mathbf{x}} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\tilde{\mathbf{y}} \right) + \tilde{\mathbf{y}}^T \boldsymbol{\Sigma}_{YY}^{-1} \tilde{\mathbf{y}}$$
#
# Substituting back $\tilde{\mathbf{x}}$ and $\tilde{\mathbf{y}}$:
#
# $$Q = (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X|Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) + (\mathbf{y} - \boldsymbol{\mu}_Y)^T \boldsymbol{\Sigma}_{YY}^{-1} (\mathbf{y} - \boldsymbol{\mu}_Y)$$
#
# where $\boldsymbol{\mu}^* = \boldsymbol{\mu}_X + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_Y)$.
#
# ---
#
# ### 3. Determinant Decomposition
# Using the property of block matrix determinants:
#
# $$|\boldsymbol{\Sigma}| = |\boldsymbol{\Sigma}_{YY}| \cdot |\boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}| = |\boldsymbol{\Sigma}_{YY}| \cdot |\boldsymbol{\Sigma}_{X|Y}|$$
#
# Taking the square root:
#
# $$\sqrt{|\boldsymbol{\Sigma}|} = \sqrt{|\boldsymbol{\Sigma}_{YY}|} \cdot \sqrt{|\boldsymbol{\Sigma}_{X|Y}|}$$
#
# ---
#
# ### 4. Combining Everything
# Now, we substitute the expanded exponent and determinant back into the conditional density formula:
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{\frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}_{X|Y}| |\boldsymbol{\Sigma}_{YY}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X|Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right) \exp\left( -\frac{1}{2} (\mathbf{y} - \boldsymbol{\mu}_Y)^T \boldsymbol{\Sigma}_{YY}^{-1} (\mathbf{y} - \boldsymbol{\mu}_Y) \right)}{\frac{1}{\sqrt{(2\pi)^m |\boldsymbol{\Sigma}_{YY}|}} \exp\left( -\frac{1}{2} (\mathbf{y} - \boldsymbol{\mu}_Y)^T \boldsymbol{\Sigma}_{YY}^{-1} (\mathbf{y} - \boldsymbol{\mu}_Y) \right)}$$
#
# The parts corresponding to the marginal distribution of $\mathbf{Y}$ cancel out completely:
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{\sqrt{(2\pi)^m |\boldsymbol{\Sigma}_{YY}|}}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}_{X|Y}| |\boldsymbol{\Sigma}_{YY}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X|Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right)$$
#
# Simplifying the constants yields the final desired expression:
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\boldsymbol{\Sigma}_{X|Y}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X|Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right)$$
#
# where:
# * $\boldsymbol{\Sigma}_{X\mid Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$
# * $\boldsymbol{\mu}^* = \boldsymbol{\mu}_X + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_Y)$

# %% [markdown]
# # Q3) Continuous Fault Monitoring of a Spindle Motor

# %% [markdown]
# A factory monitors the health of a high-speed CNC spindle. The critical variable is the **Internal Temperature ($X$)**, but because the motor is sealed, they can only observe the **Total Spindle Power ($Y$)**.
#
# **The Setup:**
# 1.  **Hidden Temperature ($X$):** The standardized temperature deviation follows a standard normal distribution:
#     $$X \sim \mathscr{N}(0, 1)$$
# 2.  **Mechanical Load ($Q$):** The torque required to cut material creates "noise" in the power reading. It is independent of temperature and follows:
#     $$Q \sim \mathscr{N}(0, 4)$$
# 3.  **The Measurement ($Y$):** The power sensor $Y$ measures the combined effect of thermal load and mechanical torque:
# $$Y = X + Q$$
#
# ---
#
# **Answer the followings:**
#
# **1. Joint Distribution**
# Identify the distribution of the random varaible $(X, Y)$.
# * Show that $Y \sim \mathscr{N}(0, 5)$.
# * Find the covariance $\text{Cov}(X, Y)=\Sigma_{XY}$.
#
# **2. Information Geometry**
# Explain why $X$ is **not** $\sigma(Y)$-measurable. In practical terms, if the power meter shows $Y = 5$, why can't the engineer know for certain if the motor is overheating ($X$ is high) or if the material being cut is simply very hard ($Q$ is high)?
#
# **3. Conditional Expectation (The Best Estimate)**
# Compute the conditional expectation $E[X \mid Y]$.
# * Using the property for joint normals: $E[X \mid Y = y] = \mu_X + \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}(y - \mu_Y)$.
# * Express this as a "signal-to-total-variance" ratio.
#
# **4. Verification of the Residual**
# Let $\widehat{X} = E[X \mid Y]$. Define the estimation error (residual) as $Z = X - \widehat{X}$.
# * Prove that $E[Z] = 0$.
# * Verify that the error $Z$ is uncorrelated with the observation $Y$ (the Orthogonality Principle).
#
# **5. Information Theory: Differential Entropy**
# * Compute the differential entropy $h(X)$.
# * Compute the conditional differential entropy $h(X \mid Y)$.
# * *Note: The variance of the conditional distribution $(X \mid Y=y)$ is given by $\sigma_{X|Y}^2 = \sigma_X^2 - \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)}$.*
#
# **6. Mutual Information**
# Calculate $I(X; Y) = h(X) - h(X \mid Y)$.
# * What percentage of the "uncertainty" about the temperature is removed by observing the power meter?
# * How would this change if the mechanical noise $Q$ had a variance of $100$ instead of $4$?
#
# **7. Diagnostic Interpretation**
# The factory manager says: *"Since $Y = X + Q$, our best estimate of temperature should just be $Y$ itself."*
# Using your result from Question 3, explain why $Y$ is a **biased** estimator of $X$ and why $E[X \mid Y]$ "shrinks" the measurement toward the mean (zero).

# %% [markdown]
# ## Sample Answer

# %% [markdown]
# \begin{aligned}
# &\textbf{1. Joint Distribution of } (X, Y) \\
# &X \sim \mathcal{N}(0,1), \quad Q \sim \mathcal{N}(0,4), \quad Y = X + Q \\
# &\mu_Y = \mathbb{E}[X + Q] = \mathbb{E}[X] + \mathbb{E}[Q] = 0 + 0 = 0 \\
# &\text{Var}(Y) = \text{Var}(X + Q) = \text{Var}(X) + \text{Var}(Q) = 1 + 4 = 5 \\
# &\text{Cov}(X,Y) = \text{Cov}(X, X+Q) = \text{Var}(X) + \text{Cov}(X,Q) = 1 + 0 = 1 \\
# &\mathbf{\mu} = \begin{bmatrix} 0 \\ 0 \end{bmatrix}, \quad \mathbf{\Sigma} = \begin{bmatrix} 1 & 1 \\ 1 & 5 \end{bmatrix} \\
# \\
# &\textbf{2. Conditional Expectation } \mathbb{E}[X|Y] \\
# &\mathbb{E}[X|Y=y] = \mu_X + \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}(y - \mu_Y) = 0 + \frac{1}{5}(Y - 0) = 0.2Y \\
# \\
# &\textbf{3. Residual Verification } (Z = X - 0.2Y) \\
# &\mathbb{E}[Z] = \mathbb{E}[X] - 0.2\mathbb{E}[Y] = 0 - 0 = 0 \\
# &\text{Cov}(Z,Y) = \text{Cov}(X - 0.2Y, Y) = \text{Cov}(X,Y) - 0.2\text{Var}(Y) = 1 - 0.2(5) = 0 \\
# \\
# &\textbf{4. Differential Entropy} \\
# &h(X) = \frac{1}{2} \ln(2\pi e \cdot \text{Var}(X)) = \frac{1}{2} \ln(2\pi e \cdot 1) \\
# &\text{Var}(X|Y) = \text{Var}(X) - \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)} = 1 - \frac{1^2}{5} = 0.8 \\
# &h(X|Y) = \frac{1}{2} \ln(2\pi e \cdot \text{Var}(X|Y)) = \frac{1}{2} \ln(2\pi e \cdot 0.8) \\
# \\
# &\textbf{5. Mutual Information} \\
# &I(X;Y) = h(X) - h(X|Y) = \frac{1}{2}\ln(2\pi e) - \frac{1}{2}\ln(2\pi e \cdot 0.8) = \frac{1}{2}\ln\left(\frac{1}{0.8}\right) = \frac{1}{2}\ln(1.25) \text{ nats} \\
# \\
# &\textbf{6. Error Variance Comparison} \\
# &\text{Naive Estimator } (\hat{X} = Y): \quad \text{Error} = X - Y = -Q \implies \text{Variance} = \text{Var}(Q) = 4 \\
# &\text{Optimal Estimator } (\hat{X} = 0.2Y): \quad \text{Variance} = \text{Var}(X|Y) = 0.8
# \end{aligned}

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from scipy.stats import multivariate_normal, norm

# --- 1. Parameters for the Spindle Problem ---
# X: Temperature ~ N(0, 1)
# Q: Torque ~ N(0, 4)
# Y: Power = X + Q => Y ~ N(0, 5)
mu_x, mu_y = 0, 0
var_x, var_q = 1, 4
var_y = var_x + var_q
cov_xy = var_x  # Cov(X, X+Q) = Var(X) = 1
rho = cov_xy / (np.sqrt(var_x) * np.sqrt(var_y))

# Shrinkage Factor (Gain)
k = cov_xy / var_y  # 1/5 = 0.2

# --- 2. Generate Data for Visualization ---
# Sample points to show the "Cloud" of data
np.random.seed(42)
n_samples = 1000
x_samples = np.random.normal(mu_x, np.sqrt(var_x), n_samples)
q_samples = np.random.normal(0, np.sqrt(var_q), n_samples)
y_samples = x_samples + q_samples
x_hat = k * y_samples  # E[X|Y]
residual = x_samples - x_hat

# Grids for Contours
x_grid = np.linspace(-4, 4, 200)
y_grid = np.linspace(-8, 8, 200)
X_m, Y_m = np.meshgrid(x_grid, y_grid)
pos = np.dstack((X_m, Y_m))
Z = multivariate_normal([mu_x, mu_y], [[var_x, cov_xy], [cov_xy, var_y]]).pdf(pos)

# --- 3. Create Simulation Plot ---
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=(
        "Joint Distribution: X vs Y<br><sup>The Line of Best Estimate (Shrinkage)</sup>",
        "Estimation Error (Residual) vs Y<br><sup>Visualizing the Orthogonality Principle</sup>"
    )
)

# --- LEFT PLOT: Joint X, Y and the Estimator ---
# Density Contour
fig.add_trace(go.Contour(
    x=x_grid, y=y_grid, z=Z, colorscale='Blues', showscale=False, opacity=0.6,
    hoverinfo='skip'
), row=1, col=1)

# Scatter of actual realizations
fig.add_trace(go.Scatter(
    x=x_samples, y=y_samples, mode='markers',
    marker=dict(color='rgba(0,0,0,0.1)', size=3),
    name="Realized (x, y)"
), row=1, col=1)

# The Best Estimate Line E[X|Y] = 0.2Y
y_line = np.linspace(-8, 8, 10)
fig.add_trace(go.Scatter(
    x=k * y_line, y=y_line,
    line=dict(color='Red', width=4),
    name="E[X|Y] = 0.2Y (Optimal)"
), row=1, col=1)

# The Naive Estimator Line X = Y
fig.add_trace(go.Scatter(
    x=y_line, y=y_line,
    line=dict(color='Black', width=2, dash='dash'),
    name="X = Y (Naive)"
), row=1, col=1)

# --- RIGHT PLOT: Orthogonality (Residual vs Y) ---
fig.add_trace(go.Scatter(
    x=y_samples, y=residual, mode='markers',
    marker=dict(color='Purple', opacity=0.4, size=4),
    name="Residual (X - 0.2Y)"
), row=1, col=2)

# Horizontal line at 0 to show no correlation
fig.add_trace(go.Scatter(
    x=y_line, y=np.zeros_like(y_line),
    line=dict(color='Black', width=2),
    name="Zero Mean Error"
), row=1, col=2)

# --- Layout and Styling ---
fig.update_layout(
    height=600,
    title_text="Spindle Motor Diagnostic Simulation: Extracting Signal from Noise",
    template="plotly_white",
    hovermode='x'
)

fig.update_xaxes(title_text="True Temperature (X)", row=1, col=1)
fig.update_yaxes(title_text="Observed Power (Y)", row=1, col=1)
fig.update_xaxes(title_text="Observed Power (Y)", row=1, col=2)
fig.update_yaxes(title_text="Residual Error (Z)", row=1, col=2)

fig.show()

# %% [markdown]
# ## Bridging Probability Theory and Industrial Diagnostics
#
# The simulation results provide a powerful bridge between abstract probability theory and practical industrial diagnostics. Below is a detailed analysis of what these results physically and mathematically imply.
#
# ### 1. The Shrinkage Principle (The "Conservative" Estimate)
# In the left plot, we compare the **Naive Estimator** ($X = Y$) with the **Optimal Estimator** ($\mathbb{E}[X|Y] = 0.2Y$).
#
# * **The Problem:** Because the noise (Torque $Q$, $\sigma^2 = 4$) is four times stronger than the signal (Temperature $X$, $\sigma^2 = 1$), the raw sensor reading $Y$ is heavily "polluted."
# * **The Result:** The optimal estimator "shrinks" the measurement by 80%. If the power meter spikes to $Y = 5$, the mathematics demonstrate that, statistically, only $1$ unit of that spike is likely due to temperature, while $4$ units are likely due to material hardness.
# * **Physical Meaning:** $\mathbb{E}[X|Y]$ prevents **False Alarms**. A naive system would trigger an emergency cooling shut-off every time the cutting tool hits a hard knot in the wood; the "shrunk" estimator correctly recognizes that $Q$ is the more probable culprit for large spikes.
#
# ### 2. The Orthogonality Principle (Efficiency)
# The right plot illustrates the **Residual Error ($Z$)** plotted against the **Observation ($Y$)**.
#
# * **The Observation:** The cloud of data points is perfectly horizontal, indicating zero correlation.
# * **The Meaning:** This proves that our estimate $0.2Y$ has extracted ("sucked out") every possible bit of information that $Y$ has to offer.
# * **The Proof:** If the plot displayed a diagonal trend, it would imply that a portion of the error could still be predicted by $Y$. Since the correlation is zero, the error behaves purely as "white noise" relative to our sensor. We have achieved the **Minimum Mean Square Error (MMSE)**.
#
# ### 3. Information Geometry & Sigma-Algebras
# The contour plot visualizes why $X$ is not $\sigma(Y)$-measurable:
#
# * Consider the vertical spread for any single $Y$ value. Even if we fix $Y = 0$, $X$ still retains a spread (a conditional variance of $0.8$).
# * Because the sensor $Y$ maps a 2D reality $(X, Q)$ down to a 1D line, information is inherently lost. The "Best Estimate" is the vertical center-point of that spread, but the "thickness" of the cloud represents the **irreducible uncertainty** ($h(X|Y)$) that this specific sensor cannot resolve.
#
# ### 4. Variance Reduction and Mutual Information
# * **Initial State:** Before taking a measurement, our baseline uncertainty (variance) about the temperature was $1.0$.
# * **After Measurement:** Our uncertainty drops to $0.8$.
# * **Information Gain:** We achieved an information gain of **$0.1116$ nats** ($I(X;Y)$).
# * **The Industrial "Why":** This $20\%$ reduction represents the physical value of the sensor. If we required a higher $I(X;Y)$, upgrading to a "better" version of $Y$ would be futile; instead, we would need a **different** sensor type (such as an acoustic sensor) that is decoupled from $Q$.
#
# ---
#
# | Concept | Result | Practical Interpretation |
# | :--- | :--- | :--- |
# | **Gain ($k=0.2$)** | Shrinkage | Don't overreact to noisy sensor spikes. |
# | **Orthogonality** | $\text{Cov}(Z, Y)=0$ | 100% of the useful data has been extracted from $Y$. |
# | **MSE ($0.8$)** | Variance Reduction | Your prediction is 20% more accurate than a blind guess. |
# | **Entropy ($h$)** | Uncertainty | Measuring $Y$ narrows the "bell curve" of possible $X$ values. |
